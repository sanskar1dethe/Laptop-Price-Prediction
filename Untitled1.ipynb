# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path

# %%
data_path = Path('laptop_price.csv')
df = pd.read_csv(data_path)

# %%
df.shape
# Out:
# (1303, 16)

# %%
df.head(10)
# Out:
#    Unnamed: 0 Company   TypeName  Inches  Touchscreen  Ips Cpu_Vender  \
# 0           0   Apple  Ultrabook    13.3            0    1      Intel
# 1           1   Apple  Ultrabook    13.3            0    0      Intel
# 2           2      HP   Notebook    15.6            0    0      Intel
# 3           3   Apple  Ultrabook    15.4            0    1      Intel
# 4           4   Apple  Ultrabook    13.3            0    1      Intel
# 5           5    Acer   Notebook    15.6            0    0        AMD
# 6           6   Apple  Ultrabook    15.4            0    1      Intel
# 7           7   Apple  Ultrabook    13.3            0    0      Intel
# 8           8    Asus  Ultrabook    14.0            0    0      Intel
# 9           9    Acer  Ultrabook    14.0            0    1      Intel
#
#          Cpu_Type  Ram  Storage (GB)   Storage Type Gpu_Vender  \
# 0         Core i5    8           128            SSD      Intel
# 1         Core i5    8           128  Flash Storage      Intel
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1303 non-null   int64
#  1   Company       1303 non-null   object
#  2   TypeName      1303 non-null   object
#  3   Inches        1303 non-null   float64
#  4   Touchscreen   1303 non-null   int64
#  5   Ips           1303 non-null   int64
#  6   Cpu_Vender    1303 non-null   object
#  7   Cpu_Type      1303 non-null   object
#  8   Ram           1303 non-null   int64
#  9   Storage (GB)  1303 non-null   int64
#  10  Storage Type  1303 non-null   object
#  11  Gpu_Vender    1303 non-null   object
#  12  Gpu_Type      1303 non-null   object
#  13  Weight        1303 non-null   float64
#  14  OpSys         1303 non-null   object
#  15  Price_euros   1303 non-null   float64
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.0+ KB

# %%
df.describe(include="all")
# Out:
#         Unnamed: 0 Company  TypeName       Inches  Touchscreen          Ips  \
# count   1303.00000    1303      1303  1303.000000  1303.000000  1303.000000
# unique         NaN      19         6          NaN          NaN          NaN
# top            NaN    Dell  Notebook          NaN          NaN          NaN
# freq           NaN     297       727          NaN          NaN          NaN
# mean     651.00000     NaN       NaN    15.017191     0.147352     0.280123
# std      376.28801     NaN       NaN     1.426304     0.354593     0.449231
# min        0.00000     NaN       NaN    10.100000     0.000000     0.000000
# 25%      325.50000     NaN       NaN    14.000000     0.000000     0.000000
# 50%      651.00000     NaN       NaN    15.600000     0.000000     0.000000
# 75%      976.50000     NaN       NaN    15.600000     0.000000     1.000000
# max     1302.00000     NaN       NaN    18.400000     1.000000     1.000000
#
# ...

# %%
plt.figure(figsize=(20,15))
sns.barplot(x='Company',y='Price_euros',data = df)
plt.xlabel('COMPANY', fontsize=15,fontweight='bold')
plt.ylabel("PRICE(in euros)", fontsize=15,fontweight='bold')
# Out:
# Text(0, 0.5, 'PRICE(in euros)')

# %%
plt.figure(figsize=(15,12))
df.groupby("Company")['Company'].count().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Company'>

# %%
df.groupby('TypeName')["TypeName"].count().sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='TypeName'>

# %%
df.groupby('Ram')["Ram"].count().sort_values(ascending=False).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='Ram'>

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='TypeName',y="Price_euros",data=df)
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Price_euros'>

# %%
df['TypeName'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
X = df.Cpu_Type.value_counts().reset_index().iloc[0:10]

# %%
plt.figure(figsize=(15,12))
sns.barplot(x=X["index"],y=X["Cpu_Type"], hue="Cpu_Vender",data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Cpu_Type'>

# %%
X1 = df.Gpu_Type.value_counts().reset_index().iloc[0:10]
X1
# Out:
#               index  Gpu_Type
# 0   HD Graphics 620       281
# 1   HD Graphics 520       185
# 2  UHD Graphics 620        68
# 3  GeForce GTX 1050        66
# 4  GeForce GTX 1060        48
# 5     GeForce 940MX        43
# 6        Radeon 530        41
# 7   HD Graphics 500        39
# 8   HD Graphics 400        37
# 9  GeForce GTX 1070        30

# %%
plt.figure(figsize=(20,12))
sns.barplot(x=X1["index"],y=X1["Gpu_Type"], hue="Gpu_Vender",data=df)
# Out:
# <AxesSubplot:xlabel='index', ylabel='Gpu_Type'>

# %%
X2=df.groupby("Cpu_Type")["Price_euros"].count().sort_values(ascending =False)[0:10].reset_index()
columns=list(X2.Cpu_Type)
X2
# Out:
#             Cpu_Type  Price_euros
# 0            Core i7          527
# 1            Core i5          423
# 2            Core i3          136
# 3  Celeron Dual Core           80
# 4          I n t e l           47
# 5             Core M           19
# 6     A9-Series 9420           12
# 7     A6-Series 9220            8
# 8  Celeron Quad Core            8
# 9   A12-Series 9720P            7

# %%
plt.figure(figsize=(15,12))
dummy = df.loc[df.Cpu_Type.isin(columns)]
sns.stripplot(x="Cpu_Type",y="Price_euros",data=dummy)
# Out:
# <AxesSubplot:xlabel='Cpu_Type', ylabel='Price_euros'>

# %%
X3=df.groupby("Storage (GB)")["Price_euros"].count().sort_values(ascending=False).reset_index()
columns2 = list(X3["Storage (GB)"])
columns2
# Out:
# [256, 1024, 128, 512, 500, 32, 64, 2048, 16, 180, 8, 240, 508]

# %%
plt.figure(figsize=(15,12))
sns.stripplot(x="Storage (GB)",y="Price_euros",data=df)
# Out:
# <AxesSubplot:xlabel='Storage (GB)', ylabel='Price_euros'>

# %%
X4=df.groupby("Gpu_Type")["Price_euros"].count().sort_values(ascending=False).reset_index()[0:20]
columns3 = list(X4["Gpu_Type"])
columns3
# Out:
# ['HD Graphics 620',
#  'HD Graphics 520',
#  'UHD Graphics 620',
#  'GeForce GTX 1050',
#  'GeForce GTX 1060',
#  'GeForce 940MX',
#  'Radeon 530',
#  'HD Graphics 500',
#  'HD Graphics 400',
#  'GeForce GTX 1070',
#  'HD Graphics',
#  'GeForce GTX 1050 Ti',
#  'Radeon R5 M430',
#  'GeForce 930MX',
#  'Radeon 520',
#  'GeForce MX150',
#  'HD Graphics 515',
#  'GeForce GTX 960M',
#  'HD Graphics 615',
#  'Radeon R7 M445']

# %%
plt.figure(figsize=(25,20))
dummy2 = df.loc[df.Gpu_Type.isin(columns3)]
sns.stripplot(x="Gpu_Type",y="Price_euros",data=dummy2)
#dummy2
# Out:
# <AxesSubplot:xlabel='Gpu_Type', ylabel='Price_euros'>

# %%
X3=df.groupby("OpSys")["Price_euros"].count().sort_values(ascending=False).reset_index()
columns4= list(X3.OpSys)

# %%
plt.figure(figsize=(10,8))
sns.stripplot(x="OpSys",y="Price_euros",data=df)
# Out:
# <AxesSubplot:xlabel='OpSys', ylabel='Price_euros'>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Company         0
# TypeName        0
# Inches          0
# Touchscreen     0
# Ips             0
# Cpu_Vender      0
# Cpu_Type        0
# Ram             0
# Storage (GB)    0
# Storage Type    0
# Gpu_Vender      0
# Gpu_Type        0
# Weight          0
# OpSys           0
# Price_euros     0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
df.Price_euros.plot.density()
plt.title("Price desity ")
# Out:
# Text(0.5, 1.0, 'Price desity ')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import mean_absolute_error
 

s = (df.dtypes=="object")
object_cols = list(s[s].index)
object_cols
# Out:
# ['Company',
#  'TypeName',
#  'Cpu_Vender',
#  'Cpu_Type',
#  'Storage Type',
#  'Gpu_Vender',
#  'Gpu_Type',
#  'OpSys']

# %%
object_cols.remove('Cpu_Vender')
object_cols.remove('Gpu_Vender')
object_cols
# Out:
# ['Company', 'TypeName', 'Cpu_Type', 'Storage Type', 'Gpu_Type', 'OpSys']

# %%
df_copy = df.copy()
ordinal_encoder = OrdinalEncoder()
df_copy[object_cols] = ordinal_encoder.fit_transform((df_copy[object_cols]))
df_copy
# Out:
#       Unnamed: 0  Company  TypeName  Inches  Touchscreen  Ips Cpu_Vender  \
# 0              0      1.0       4.0    13.3            0    1      Intel
# 1              1      1.0       4.0    13.3            0    0      Intel
# 2              2      7.0       3.0    15.6            0    0      Intel
# 3              3      1.0       4.0    15.4            0    1      Intel
# 4              4      1.0       4.0    13.3            0    1      Intel
# ...          ...      ...       ...     ...          ...  ...        ...
# 1298        1298     10.0       0.0    14.0            1    1      Intel
# 1299        1299     10.0       0.0    13.3            1    1      Intel
# 1300        1300     10.0       3.0    14.0            0    0      Intel
# 1301        1301      7.0       3.0    15.6            0    0      Intel
# 1302        1302      2.0       3.0    15.6            0    0      Intel
#
#       Cpu_Type  Ram  Storage (GB)  Storage Type Gpu_Vender  Gpu_Type  Weight  \
# ...

# %%
corr_scores = df_copy.corr()
y = df_copy.Price_euros
y= pd.DataFrame(y)
df_copy.pop("Price_euros")
X = df_copy.copy()

# %%
X.drop(['Unnamed: 0','Cpu_Vender','Gpu_Vender'],axis=1,inplace=True)
X
# Out:
#       Company  TypeName  Inches  Touchscreen  Ips  Cpu_Type  Ram  \
# 0         1.0       4.0    13.3            0    1      17.0    8
# 1         1.0       4.0    13.3            0    0      17.0    8
# 2         7.0       3.0    15.6            0    0      17.0    8
# 3         1.0       4.0    15.4            0    1      18.0   16
# 4         1.0       4.0    13.3            0    1      17.0    8
# ...       ...       ...     ...          ...  ...       ...  ...
# 1298     10.0       0.0    14.0            1    1      18.0    4
# 1299     10.0       0.0    13.3            1    1      18.0   16
# 1300     10.0       3.0    14.0            0    0      13.0    2
# 1301      7.0       3.0    15.6            0    0      18.0    6
# 1302      2.0       3.0    15.6            0    0      13.0    4
#
#       Storage (GB)  Storage Type  Gpu_Type  Weight  OpSys
# 0              128           5.0      60.0    1.37    0.0
# 1              128           0.0      53.0    1.34    0.0
# ...

# %%
X.drop(['Touchscreen','Ips','OpSys'],axis=1,inplace = True)
X
# Out:
#       Company  TypeName  Inches  Cpu_Type  Ram  Storage (GB)  Storage Type  \
# 0         1.0       4.0    13.3      17.0    8           128           5.0
# 1         1.0       4.0    13.3      17.0    8           128           0.0
# 2         7.0       3.0    15.6      17.0    8           256           5.0
# 3         1.0       4.0    15.4      18.0   16           512           5.0
# 4         1.0       4.0    13.3      17.0    8           256           5.0
# ...       ...       ...     ...       ...  ...           ...           ...
# 1298     10.0       0.0    14.0      18.0    4           128           5.0
# 1299     10.0       0.0    13.3      18.0   16           512           5.0
# 1300     10.0       3.0    14.0      13.0    2            64           0.0
# 1301      7.0       3.0    15.6      18.0    6          1024           2.0
# 1302      2.0       3.0    15.6      13.0    4           500           2.0
#
#       Gpu_Type  Weight
# 0         60.0    1.37
# ...

# %%
X_train,X_test,y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)
reg1 = LinearRegression()
reg1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(mean_absolute_error(y_test,reg1.predict(X_test)))
reg1.score(X_test,y_test)
# Out:
# 335.384808946574
# 0.5909558427135542

# %%
from sklearn.svm import SVR
sv_regressor = SVR(kernel="linear")
sv_regressor.fit(X_train,np.ravel(y_train))
sv_regressor.score(X_test,np.ravel(y_test))
# Out:
# 0.5642721241413009

# %%
sv_regressor = SVR(kernel="poly",degree=10)
sv_regressor.fit(X_train,np.ravel(y_train))
sv_regressor.score(X_test,np.ravel(y_test))
# Out:
# -1.1292241783478714

# %%
corr_scores
# Out:
#               Unnamed: 0   Company  TypeName    Inches  Touchscreen       Ips  \
# Unnamed: 0      1.000000  0.106897 -0.083174 -0.087936     0.051547 -0.024031
# Company         0.106897  1.000000 -0.007718 -0.085784     0.038703  0.118205
# TypeName       -0.083174 -0.007718  1.000000 -0.077428    -0.417188 -0.162855
# Inches         -0.087936 -0.085784 -0.077428  1.000000    -0.361735 -0.114804
# Touchscreen     0.051547  0.038703 -0.417188 -0.361735     1.000000  0.150512
# Ips            -0.024031  0.118205 -0.162855 -0.114804     0.150512  1.000000
# Cpu_Type       -0.007981  0.035102 -0.082129  0.000570     0.059720  0.069274
# Ram            -0.028571  0.046508 -0.242862  0.237993     0.116984  0.206623
# Storage (GB)   -0.001530 -0.084573  0.070773  0.269718    -0.031904 -0.119641
# Storage Type   -0.069172  0.104251 -0.197083  0.181533     0.046942  0.186302
# Gpu_Type       -0.131168 -0.062926  0.210814 -0.200117     0.126174 -0.047017
# ...

# %%
discrete_features = (X.dtypes== int)
from sklearn.feature_selection import mutual_info_regression
mi_scores = mutual_info_regression(X,y,discrete_features=discrete_features)
mi_scores = pd.Series(mi_scores,name="MI Scores",index=X.columns)
mi_scores
# Out:
# c:\users\sanskar dethe\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Company         0.138119
# TypeName        0.303814
# Inches          0.214994
# Touchscreen     0.030586
# Ips             0.051800
# Cpu_Type        0.565043
# Ram             0.510741
# Storage (GB)    0.404987
# Storage Type    0.302326
# Gpu_Type        0.572686
# Weight          0.314561
# OpSys           0.085329
# Name: MI Scores, dtype: float64

# %%
X.drop(['Touchscreen','Ips','OpSys'],axis=1,inplace = True)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X
# Out:
#       Company  TypeName  Inches  Cpu_Type  Ram  Storage (GB)  Storage Type  \
# 0         1.0       4.0    13.3      17.0    8           128           5.0
# 1         1.0       4.0    13.3      17.0    8           128           0.0
# 2         7.0       3.0    15.6      17.0    8           256           5.0
# 3         1.0       4.0    15.4      18.0   16           512           5.0
# 4         1.0       4.0    13.3      17.0    8           256           5.0
# ...       ...       ...     ...       ...  ...           ...           ...
# 1298     10.0       0.0    14.0      18.0    4           128           5.0
# 1299     10.0       0.0    13.3      18.0   16           512           5.0
# 1300     10.0       3.0    14.0      13.0    2            64           0.0
# 1301      7.0       3.0    15.6      18.0    6          1024           2.0
# 1302      2.0       3.0    15.6      13.0    4           500           2.0
#
#       Gpu_Type  Weight
# 0         60.0    1.37
# ...

# %%
X_train,X_test,y_train, y_test = train_test_split(X,y,random_state=0,test_size=0.2)
X_scaled = scaler.fit_transform(X_train)
X_scaled= pd.DataFrame(X_scaled)
y_scaled = scaler.fit_transform(y_train)
y_scaled = pd.DataFrame(y_scaled)
reg1 = LinearRegression()
reg1.fit(X_scaled,y_scaled)
# Out:
# LinearRegression()

# %%
X_test_scaled = scaler.fit_transform(X_test)
y_test_scaled = scaler.fit_transform(y_test)
reg1.score(X_test_scaled,y_test_scaled)
# Out:
# 0.5953482048720311

# %%
 X_scaled
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.590901 -2.098874 -1.210095 -0.027116 -0.045270 -0.528224  0.430151
# 1    -0.590901 -2.098874  0.411621  0.267202  1.540320  0.150012  0.430151
# 2     0.893354  0.322189  0.411621  3.210378 -0.838065  0.118219 -1.023527
# 3     0.151227  0.322189  0.411621 -2.970292 -0.838065  0.118219 -1.023527
# 4     2.377610  1.129210 -1.210095  0.267202  4.711500  0.150012  0.430151
# ...        ...       ...       ...       ...       ...       ...       ...
# 1037 -1.085652  1.129210 -1.210095 -0.027116 -0.045270 -0.528224  0.430151
# 1038 -0.590901 -1.291853  0.411621  0.267202  1.540320 -0.528224  1.399270
# 1039 -1.580404  0.322189  1.610280 -0.321433 -0.838065  1.506482 -1.023527
# 1040 -0.590901  0.322189  0.411621 -0.321433 -0.838065  1.506482 -1.023527
# 1041  0.893354 -2.098874 -1.210095  0.267202 -0.045270  0.150012  0.430151
#
#              7         8
# 0     0.117994 -1.213582
# ...

# %%
 y_scaled
# Out:
#              0
# 0     1.057829
# 1     0.122326
# 2    -1.109765
# 3    -1.028610
# 4     2.512729
# ...        ...
# 1037  0.048548
# 1038  2.476770
# 1039 -0.734974
# 1040 -0.705610
# 1041  0.594504
#
# [1042 rows x 1 columns]

# %%
from sklearn.svm import SVR
sv_regressor = SVR(kernel="linear")
sv_regressor.fit(X_scaled,y_scaled)
# Out:
# c:\users\sanskar dethe\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
sv_regressor.score(X_test_scaled,y_test_scaled)
# Out:
# 0.5833064688565492

# %%
sv_regressor = SVR(kernel="poly",degree=2)
sv_regressor.fit(X_scaled,y_scaled)
sv_regressor.score(X_test_scaled,y_test_scaled)
# Out:
# c:\users\sanskar dethe\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.4453239162762517

# %%
import numpy as np
sv_regressor = SVR(kernel="rbf")
sv_regressor.fit(X_scaled,np.ravel(y_scaled))
sv_regressor.score(X_test_scaled,np.ravel(y_test_scaled))
# Out:
# 0.6220461949502787

# %%
from sklearn.tree import DecisionTreeRegressor
dtregressor = DecisionTreeRegressor(max_leaf_nodes=85,random_state=0)
dtregressor.fit(X_train,y_train)
dtregressor.score(X_test,y_test)
# Out:
# 0.6940778791352913

# %%
from sklearn.ensemble import RandomForestRegressor
rfregressor = RandomForestRegressor(n_estimators=100,random_state=0)
rfregressor.fit(X_train,y_train)
rfregressor.score(X_test,y_test)
# Out:
# C:\Users\SANSKA~1\AppData\Local\Temp/ipykernel_9520/3892176699.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rfregressor.fit(X_train,y_train)
# 0.8128333587533398
